# %% [markdown]
# <a href="https://colab.research.google.com/github/galindovil/Tarea_geopanda/blob/main/tarea_grafico_poblacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install shapely

# %%
import geopandas as gpd
gdf_localidades=gpd.read_file("localidades.json")
gdf_localidades
# Out:
#     OBJECTID           LocNombre                            LocAAdmini  \
# 0         81      ANTONIO NARIÑO                   Acuerdo 117 de 2003
# 1         82          TUNJUELITO                   Acuerdo 117 de 2003
# 2         83  RAFAEL URIBE URIBE                   Acuerdo 117 de 2003
# 3         84          CANDELARIA                   Acuerdo 117 de 2003
# 4         85      BARRIOS UNIDOS                     Acuerdo 8 de 1977
# 5         86         TEUSAQUILLO                     Acuerdo 8 de 1977
# 6         87       PUENTE ARANDA                     Acuerdo 8 de 1977
# 7         88        LOS MARTIRES                     Acuerdo 8 de 1977
# 8         89             SUMAPAZ                     Acuerdo 9 de 1986
# 9         90             USAQUEN  Acuerdo 8 de 1977 y Res 1751 de 2016
# 10        91           CHAPINERO  Acuerdo 8 de 1977 y Res 1751 de 2016
# 11        92            SANTA FE                   Acuerdo 117 de 2003
# ...

# %%
gdf_localidades.to_crs(epsg=9377, inplace=True)

# %%
gdf_localidades.crs
# Out:
# <Projected CRS: EPSG:9377>
# Name: MAGNA-SIRGAS 2018 / Origen-Nacional
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[east]: Easting (metre)
# Area of Use:
# - name: Colombia - onshore and offshore. Includes San Andres y Providencia, Malpelo Islands, Roncador Bank, Serrana Bank and Serranilla Bank.
# - bounds: (-84.77, -4.23, -66.87, 15.51)
# Coordinate Operation:
# - name: Colombia Transverse Mercator
# - method: Transverse Mercator
# Datum: Marco Geocentrico Nacional de Referencia 2018
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
gdf_localidades
# Out:
#     OBJECTID           LocNombre                            LocAAdmini  \
# 0         81      ANTONIO NARIÑO                   Acuerdo 117 de 2003
# 1         82          TUNJUELITO                   Acuerdo 117 de 2003
# 2         83  RAFAEL URIBE URIBE                   Acuerdo 117 de 2003
# 3         84          CANDELARIA                   Acuerdo 117 de 2003
# 4         85      BARRIOS UNIDOS                     Acuerdo 8 de 1977
# 5         86         TEUSAQUILLO                     Acuerdo 8 de 1977
# 6         87       PUENTE ARANDA                     Acuerdo 8 de 1977
# 7         88        LOS MARTIRES                     Acuerdo 8 de 1977
# 8         89             SUMAPAZ                     Acuerdo 9 de 1986
# 9         90             USAQUEN  Acuerdo 8 de 1977 y Res 1751 de 2016
# 10        91           CHAPINERO  Acuerdo 8 de 1977 y Res 1751 de 2016
# 11        92            SANTA FE                   Acuerdo 117 de 2003
# ...

# %%
gdf_localidades["area"]=gdf_localidades.area/1000000

# %%
gdf_localidades
# Out:
#     OBJECTID           LocNombre                            LocAAdmini  \
# 0         81      ANTONIO NARIÑO                   Acuerdo 117 de 2003
# 1         82          TUNJUELITO                   Acuerdo 117 de 2003
# 2         83  RAFAEL URIBE URIBE                   Acuerdo 117 de 2003
# 3         84          CANDELARIA                   Acuerdo 117 de 2003
# 4         85      BARRIOS UNIDOS                     Acuerdo 8 de 1977
# 5         86         TEUSAQUILLO                     Acuerdo 8 de 1977
# 6         87       PUENTE ARANDA                     Acuerdo 8 de 1977
# 7         88        LOS MARTIRES                     Acuerdo 8 de 1977
# 8         89             SUMAPAZ                     Acuerdo 9 de 1986
# 9         90             USAQUEN  Acuerdo 8 de 1977 y Res 1751 de 2016
# 10        91           CHAPINERO  Acuerdo 8 de 1977 y Res 1751 de 2016
# 11        92            SANTA FE                   Acuerdo 117 de 2003
# ...

# %%
gdf_localidades["Centroides"]=gdf_localidades.centroid
gdf_localidades
# Out:
#     OBJECTID           LocNombre                            LocAAdmini  \
# 0         81      ANTONIO NARIÑO                   Acuerdo 117 de 2003
# 1         82          TUNJUELITO                   Acuerdo 117 de 2003
# 2         83  RAFAEL URIBE URIBE                   Acuerdo 117 de 2003
# 3         84          CANDELARIA                   Acuerdo 117 de 2003
# 4         85      BARRIOS UNIDOS                     Acuerdo 8 de 1977
# 5         86         TEUSAQUILLO                     Acuerdo 8 de 1977
# 6         87       PUENTE ARANDA                     Acuerdo 8 de 1977
# 7         88        LOS MARTIRES                     Acuerdo 8 de 1977
# 8         89             SUMAPAZ                     Acuerdo 9 de 1986
# 9         90             USAQUEN  Acuerdo 8 de 1977 y Res 1751 de 2016
# 10        91           CHAPINERO  Acuerdo 8 de 1977 y Res 1751 de 2016
# 11        92            SANTA FE                   Acuerdo 117 de 2003
# ...

# %%
import pandas as pd
poblacion=pd.read_csv("osb_demografia-poblacion-localidad.csv",encoding="latin1",delimiter=";")
poblacion.head()
# Out:
#     Año  Cod_Loc Localidad     Sexo  Edad Grupo_Edad  Población
# 0  2005        1   Usaquén  Hombres     0    00 a 04       2909
# 1  2005        1   Usaquén  Hombres     1    00 a 04       2954
# 2  2005        1   Usaquén  Hombres     2    00 a 04       2919
# 3  2005        1   Usaquén  Hombres     3    00 a 04       2989
# 4  2005        1   Usaquén  Hombres     4    00 a 04       3079

# %%
poblacion_2024= poblacion[poblacion['Año']==2024]
poblacion_2024.head()
# Out:
#         Año  Cod_Loc Localidad     Sexo  Edad Grupo_Edad  Población
# 76760  2024        1   Usaquén  Hombres     0    00 a 04       3128
# 76761  2024        1   Usaquén  Hombres     1    00 a 04       3147
# 76762  2024        1   Usaquén  Hombres     2    00 a 04       3139
# 76763  2024        1   Usaquén  Hombres     3    00 a 04       3106
# 76764  2024        1   Usaquén  Hombres     4    00 a 04       3037

# %%
#agrupar los datos por localidad
grupos=poblacion_2024.groupby("Localidad")
print(grupos)
#sumar cada localidad
total_poblacion_localidad=grupos["Población"].sum()
print(total_poblacion_localidad)
# Out:
# ...
# Localidad
# Antonio Nariño          84979
# Barrios Unidos         156268
# Bogotá                7929539
# Bosa                   733740
# Chapinero              182103
# Ciudad Bolívar         666809
# Engativá               819441
# Fontibón               408155
# Kennedy               1037929
# La Candelaria           18675
# Los Mártires            83001
# Puente Aranda          258034
# Rafael Uribe Uribe     391588
# San Cristóbal          409106
# Santa Fe               107906
# Suba                  1313453
# Sumapaz                  3926
# Teusaquillo            165438
# Tunjuelito             184492
# Usaquén                594611
# Usme                   414995
# Name: Población, dtype: int64

# %%
df_poblacion_localidad=total_poblacion_localidad.reset_index()
df_poblacion_localidad
# Out:
#              Localidad  Población
# 0       Antonio Nariño      84979
# 1       Barrios Unidos     156268
# 2               Bogotá    7929539
# 3                 Bosa     733740
# 4            Chapinero     182103
# 5       Ciudad Bolívar     666809
# 6             Engativá     819441
# 7             Fontibón     408155
# 8              Kennedy    1037929
# 9        La Candelaria      18675
# 10        Los Mártires      83001
# 11       Puente Aranda     258034
# 12  Rafael Uribe Uribe     391588
# 13       San Cristóbal     409106
# 14            Santa Fe     107906
# 15                Suba    1313453
# 16             Sumapaz       3926
# 17         Teusaquillo     165438
# 18          Tunjuelito     184492
# 19             Usaquén     594611
# 20                Usme     414995

# %%
df_poblacion_localidad["Localidad"]=df_poblacion_localidad["Localidad"].str.upper()
df_poblacion_localidad
# Out:
#              Localidad  Población
# 0       ANTONIO NARIÑO      84979
# 1       BARRIOS UNIDOS     156268
# 2               BOGOTÁ    7929539
# 3                 BOSA     733740
# 4            CHAPINERO     182103
# 5       CIUDAD BOLÍVAR     666809
# 6             ENGATIVÁ     819441
# 7             FONTIBÓN     408155
# 8              KENNEDY    1037929
# 9        LA CANDELARIA      18675
# 10        LOS MÁRTIRES      83001
# 11       PUENTE ARANDA     258034
# 12  RAFAEL URIBE URIBE     391588
# 13       SAN CRISTÓBAL     409106
# 14            SANTA FE     107906
# 15                SUBA    1313453
# 16             SUMAPAZ       3926
# 17         TEUSAQUILLO     165438
# 18          TUNJUELITO     184492
# 19             USAQUÉN     594611
# 20                USME     414995

# %%
def replace_accents(input_str):
    replacements={
        'Á':'A',
        'É':'E',
        'Í':'I',
        'Ó':'O',
        'Ú':'U',
    }
    for accented_char,unaccented_char in replacements.items():
        input_str=input_str.replace(accented_char,unaccented_char)
    return input_str

df_poblacion_localidad["Localidad"]=df_poblacion_localidad["Localidad"].apply(replace_accents)
df_poblacion_localidad
# Out:
#              Localidad  Población
# 0       ANTONIO NARIÑO      84979
# 1       BARRIOS UNIDOS     156268
# 2               BOGOTA    7929539
# 3                 BOSA     733740
# 4            CHAPINERO     182103
# 5       CIUDAD BOLIVAR     666809
# 6             ENGATIVA     819441
# 7             FONTIBON     408155
# 8              KENNEDY    1037929
# 9        LA CANDELARIA      18675
# 10        LOS MARTIRES      83001
# 11       PUENTE ARANDA     258034
# 12  RAFAEL URIBE URIBE     391588
# 13       SAN CRISTOBAL     409106
# 14            SANTA FE     107906
# 15                SUBA    1313453
# 16             SUMAPAZ       3926
# 17         TEUSAQUILLO     165438
# 18          TUNJUELITO     184492
# 19             USAQUEN     594611
# 20                USME     414995

# %%
filas=df_poblacion_localidad["Localidad"]=="LA CANDELARIA"
filas
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# Name: Localidad, dtype: bool

# %%
columna="Localidad"


df_poblacion_localidad.loc[filas,columna]="CANDELARIA"
df_poblacion_localidad
# Out:
#              Localidad  Población
# 0       ANTONIO NARIÑO      84979
# 1       BARRIOS UNIDOS     156268
# 2               BOGOTA    7929539
# 3                 BOSA     733740
# 4            CHAPINERO     182103
# 5       CIUDAD BOLIVAR     666809
# 6             ENGATIVA     819441
# 7             FONTIBON     408155
# 8              KENNEDY    1037929
# 9           CANDELARIA      18675
# 10        LOS MARTIRES      83001
# 11       PUENTE ARANDA     258034
# 12  RAFAEL URIBE URIBE     391588
# 13       SAN CRISTOBAL     409106
# 14            SANTA FE     107906
# 15                SUBA    1313453
# 16             SUMAPAZ       3926
# 17         TEUSAQUILLO     165438
# 18          TUNJUELITO     184492
# 19             USAQUEN     594611
# 20                USME     414995

# %%
localidades_bk = df_poblacion_localidad
# !pip install contextily
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 44.1 MB/s eta 0:00:00
# ...

# %%
gdf_localidades.plot()
# Out:
# <Axes: >

# %%
gdf_localidades['Centroides'] = gdf_localidades.centroid
mapa = gdf_localidades.plot(figsize=(10,10))
gdf_localidades["Centroides"].plot(ax=mapa, color="white")
# Out:
# <Axes: >

# %%
import contextily as cx

mapa_2=gdf_localidades.plot(
    column="LocNombre",
    figsize=(15,15),
    edgecolor="black",
    cmap="tab20",
    legend=True,
    legend_kwds={
        "loc":"upper left"
    }

)


cx.add_basemap(mapa_2,crs=gdf_localidades.crs.to_string())

# %%
merged_df =gdf_localidades.merge(df_poblacion_localidad,left_on='LocNombre', right_on='Localidad')
merged_df.drop('Localidad',axis=1,inplace=True)

# %%
if not isinstance(merged_df, gpd.GeoDataFrame):
    merged_df = gpd.GeoDataFrame(merged_df, geometry='geometry')

# %%
import contextily as cx
import matplotlib.pyplot as plt


fig, ax = plt.subplots(figsize=(10, 10))


merged_df.plot(column='Población', cmap='GnBu_r', legend=True, ax=ax)


cx.add_basemap(ax, crs=merged_df.crs.to_string(), source=cx.providers.OpenStreetMap.Mapnik, zoom=10)


for idx, row in merged_df.iterrows():
    centroid = row['geometry'].centroid
    ax.text(centroid.x, centroid.y, row['Población'], fontsize=6, ha='center', va='center', color='black')

plt.legend(title='Localidades', loc='lower right')

plt.title('Mapa de Localidades con Población')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
